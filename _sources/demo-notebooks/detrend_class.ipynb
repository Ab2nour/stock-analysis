# %% [markdown]
# # How to use detrend classes

# %%
import pandas as pd

from src.functions.detrend import (
    BSplinesDetrend,
    ExponentialMADetrend,
    LinearMADetrend,
    LinearRegressionDetrend,
    PolynomialRegressionDetrend,
)
from src.utils.misc import init_notebook

# %%
init_notebook()

# %%
# Lecture des données
data_folder = "data/raw"
stock_name = "AAPL"
df = pd.read_csv(
    f"{data_folder}/{stock_name}.csv", parse_dates=["Date"], index_col="Date"
)
y = df["Close"]

# %%
models = [
    LinearRegressionDetrend(),
    PolynomialRegressionDetrend(order=5, n_segments=15),
    LinearMADetrend(window=500),
    ExponentialMADetrend(alpha=0.9),
    BSplinesDetrend(interval_length=50, degree=3),
]

# %%
for detrend_model in models:
    y_fitted = detrend_model.fit(y)
    y_detrend = detrend_model.predict(y)
    detrend_model.fancy_plot(xticklabels=df.index.strftime("%Y-%m-%d"))
# Out:
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# c:\Users\jules\Desktop\Cours\DataScience\stock-analysis\src\functions\detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
