# %% [markdown]
# # How to use detrend classes

# %%
import pandas as pd
import seaborn as sns

from src.functions.detrend import (
    BSplines,
    ExponentialMA,
    LinearMA,
    LinearReg,
    PolynomialRegression,
)

# %%
sns.set_theme()
# Lecture des données
data_folder = "../data/raw_data/"
stock_name = "AAPL"
df = pd.read_csv(
    f"{data_folder}/{stock_name}.csv", parse_dates=["Date"], index_col="Date"
)
y = df["Close"]

# %%
models = [
    LinearReg(),
    PolynomialRegression(order=5, n_segments=15),
    LinearMA(window=500),
    ExponentialMA(alpha=0.9),
    BSplines(smoothing_factor=50, degree=3),
]

# %%
for detrend_model in models:
    y_fitted = detrend_model.fit(y)
    y_detrend = detrend_model.predict(y)
    detrend_model.fancy_plot(xticklabels=df.index.strftime("%Y-%m-%d"))
# Out:
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(xticklabels)
# /home/ab2/Documents/GitHub/stock-analysis/src/functions/detrend_fancy_plot.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(xticklabels)
